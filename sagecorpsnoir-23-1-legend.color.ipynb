# %%
c=3e8;h=6.626*(10^-34);k = 1.281*(10^-23)
k1=8*pi*h*c;k2=(h*c)/k
E(l,T)=k1*(l*1e-9)^-5*(1/(exp(k2/((l*1e-9)*T))-1))
f1=0;f2=E(l,3500);f3=E(l,4000);
f4=E(l,4500);f5=E(l,5000)
params=dict(figsize=4,axes=False,
            fontsize=6,
            frame=True,gridlines="major",
            gridlinesstyle=dict(
                color="cyan",
                linestyle="-",alpha=0.3),
            axes_labels=(
                "$\Lambda[nm]$",\
                "$E(\\Lambda)[KJ/nm$"),
            legend_font_size=10)
p0=plot([f1],l,10,4000,fill=f2,
       legend_label="3000",
       fillcolor=["green"],
       fillalpha=1,color="green")
p1=plot([f2],l,10,4000,fill=f3,
       legend_label="3500",
       fillcolor=["violet"],
       fillalpha=1,color="violet")
p2=plot([f3],l,10,4000,fill =f4,
       legend_label="4500",
          fillcolor=['yellow'],
          fillalpha=1,color="yellow")
p3=plot([f4],l,10,4000,fill =f5,
       legend_label="5000",
       fillcolor="red",
       fillalpha=1,color="red")
v=plot(p0+p1+p2+p3)
v.axes_color("brown")
v.axes_label_color("red")
v.tick_label_color("green")
v.show(**params)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
c=3e8;h=6.626*(10^-34);k = 1.281*(10^-23)
k1=8*pi*h*c;k2=(h*c)/k
E(l,T)=k1*(l*1e-9)^-5*(1/(exp(k2/((l*1e-9)*T))-1))
f1=0;f2=E(l,3500);f3=E(l,4000);
f4=E(l,4500);f5=E(l,5000)
params=dict(figsize=10,axes=False,fontsize=6,
            frame=True,gridlines="minor",
            gridlinesstyle=dict(color="lightsalmon",
                                linestyle="-"),
            axes_labels=("$\Lambda[nm]$","$E(\\Lambda)[KJ/nm$"),
            legend_font_size=15)
p0=plot([f1],l,10,4000,fill=f2,
       legend_label="2500",
       fillcolor=["green"],
       fillalpha=1,color="green")
p1=plot([f2],l,10,4000,fill=f3,
       legend_label="3500",
       fillcolor=["violet"],
       fillalpha=1,color="violet")
p2=plot([f3],l,10,4000,fill =f4,
       legend_label="4500",
          fillcolor=['yellow'],
          fillalpha=1,color="yellow")
p3=plot([f4],l,10,4000,fill =f5,
       legend_label="5500",
       fillcolor="red",
       fillalpha=1,color="red")
v=plot(p0+p1+p2+p3)
v.show(**params)
# Out:
# Graphics object consisting of 8 graphics primitives
