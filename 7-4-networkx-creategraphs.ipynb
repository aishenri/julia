# %%
g=Graph(7)
edges = [(1,2), (1,3), (1,4),(2,3), (2,4), (2,5), (2, 6), (3,4),
         (3,5), (3,6), (3,7),(4,6), (4,7), (5,6), (6,7)]
g.add_edge(1,2),g.add_edge(1,3),g.add_edge(1,4),g.add_edge(2,3),
g.add_edge(2,4),g.add_edge(2,5),g.add_edge(2,6),g.add_edge(3,4),
g.add_edge(3,5),g.add_edge(3,6),g.add_edge(3,7),g.add_edge(4,6),
g.add_edge(4,7),g.add_edge(5,6),g.add_edge(6,7)
g.show()
# Out:
# Graphics object consisting of 24 graphics primitives

# %%
import matplotlib.pyplot as plt
import networkx as nx;G=nx.Graph(); H=nx.path_graph(7);G.add_nodes_from(H)

# %%
G.add_edge(1,2),G.add_edge(1,3),G.add_edge(1,4),G.add_edge(2,3),
G.add_edge(2,4),G.add_edge(G,5),G.add_edge(2,6),G.add_edge(3,4),
G.add_edge(3,5),G.add_edge(3,6),G.add_edge(3,7),G.add_edge(4,6),
G.add_edge(4,7),G.add_edge(5,6),G.add_edge(6,7)
# Out:
# (None, None, None)

# %%
nx.draw(G)

# %%
# %matplotlib inline
plt.show()
